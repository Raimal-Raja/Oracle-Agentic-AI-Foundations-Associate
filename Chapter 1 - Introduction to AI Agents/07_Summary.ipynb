# %% [markdown]
# # Module 1 Summary — Introduction to AI Agents
#
# ## Congratulations!
#
# Congratulations on completing the first module of the **Oracle Agentic AI Foundations** course.
#
# In this module, we introduced the fundamental concepts behind AI agents and explored how they differ from traditional large language model applications and fixed workflows.
#
# We covered:
#
# - What an AI agent is
# - LLM-based AI agents
# - The three core components of an agent
# - LLMs as the agent's brain
# - Tools as the agent's hands
# - The agent execution loop
# - Agent orchestration
# - Chain of Thought
# - ReAct reasoning
# - Building a simple AI agent
# - Dynamic multi-step reasoning
# - Agent security and guardrails
#
# Let's review the most important concepts from the module.
#
# ---
#
# # 1. What Is an AI Agent?
#
# In classical AI, an agent can be defined as:
#
# > A system that perceives its environment and takes actions within that environment.
#
# In this course, the focus is specifically on **LLM-based AI agents**.
#
# The fundamental mental model is:
#
# ```text
# LLM-Based AI Agent
#        |
#        +----------------+
#        |                |
#        v                v
#       LLM             Tools
#        |                |
#        |                |
#        +-------+--------+
#                |
#                v
#              Loop
