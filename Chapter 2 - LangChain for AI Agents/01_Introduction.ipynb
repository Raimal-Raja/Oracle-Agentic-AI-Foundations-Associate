# %% [markdown]
# # Module 2: LangChain for AI Agents
#
# ## Introduction
#
# Welcome to the **LangChain for AI Agents** module.
#
# In the previous module, we learned the fundamental concepts behind AI agents, including:
#
# - Large Language Models (LLMs)
# - Tools
# - Agent execution loops
# - Reasoning patterns
# - ReAct
# - Creating a simple AI agent
#
# In this module, we will build on those foundations and explore how **LangChain** helps developers create and orchestrate AI agents.
#
# The goal is not only to use LangChain, but also to understand the concepts and internal processes that make LangChain-based agents work.
#
# ---
#
# # What You Will Learn
#
# This module is divided into three main lessons:
#
# 1. **LangChain Basics**
# 2. **Building a Simple Agent with LangChain**
# 3. **Understanding What Happens Under the Hood**
#
# ---
#
# ## Lesson 1: LangChain Basics
#
# The first lesson introduces the fundamentals of the LangChain framework.
#
# We will explore several important LangChain components, including:
#
# - Models
# - Prompts
# - Chains
#
# These components form the foundation of many LangChain applications.
#
# ### Models
#
# A model is the AI or LLM that powers the application.
#
# The model is responsible for understanding user input, reasoning about problems, generating responses, and deciding what actions may be required.
#
# Conceptually:
#
# ```text
# User Input
#     ↓
# LLM / Model
#     ↓
# Generated Response
